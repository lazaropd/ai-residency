# %%
import pandas as pd
import random
from scipy.stats import bernoulli
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4, 8, 10,25])

plt.ylabel('Números quaisquer')

plt.show()

# %%
import matplotlib.pyplot as plt

x=[2, 3, 4, 5, 6, 7,8]
y=[1, 2, 3, 4, 8, 10,25]
plt.plot(x,y)

plt.ylabel('Números quaisquer')

plt.show()

# %%
fig = plt.figure()  # an empty figure with no axes
fig.suptitle('No axes on this figure')  # Add a title so we know which it is

fig, ax_lst = plt.subplots(1, 1)  # a figure with a 2x2 grid of Axes
plt.show()

# %%
#Criando um conjunto de valores aleatórios
x = np.arange(0, 10, 0.2)

#Criando 3 distribuições aplicando funçõesm matemáticas em valores aleatórios
y = np.sin(x)
z = np.cos(x)
w = np.tan(x)

#Criando 3 axes - um para cada gráfico
fig, ax_lst = plt.subplots(1, 3)
ax_lst[0].plot(x, y)
ax_lst[1].plot(x, z)
ax_lst[2].plot(x, w)
plt.show()

#Criando 3 axes - um para cada gráfico
fig, ax_lst = plt.subplots(3, 1)
ax_lst[0].plot(x, y)
ax_lst[1].plot(x, z)
ax_lst[2].plot(x, w)
plt.show()

#Utilizando o mesmo axe para duas distribuições
fig, ax_lst = plt.subplots(1, 2)
ax_lst[0].plot(x, y)
ax_lst[0].plot(x, z)
ax_lst[1].plot(x, w)
plt.show()

#Utilizando o mesmo axe para as três distribuições, usando 2 eixos
fig, ax_lst = plt.subplots(1, 1)
ax_lst.plot(x, y)
ax_lst.plot(x, z)
ax_lst.twinx()
ax_lst.plot(x, w)
plt.show()

# %%
import numpy as np

# Gerando intervalo aleatório
t = np.arange(0., 5., 0.2)

# Diferentes marcadores de ponto
line_1, = plt.plot(t, t, 'r--' , label='Linha t')
line_2, = plt.plot(t, t**2, 'bs' , label='Linha t*2')
line_3, = plt.plot(t, t**3, 'g^' , label='Linha t*3')

#labels
plt.xlabel('eixo x')
plt.ylabel('eixo y')
plt.suptitle('titulo do grafico')

#legenda
plt.legend([line_1, line_2, line_3], ['linha t', 'linha t*2','linha t*3'], loc='upper right')

plt.show()

# %%
#probabilidade de eventos independentes
for i in range(10):
    print(random.choice(["boy", "girl"]))
# Out:
# girl
# boy
# girl
# boy
# girl
# boy
# boy
# boy
# girl
# girl

# %% [markdown]
# ## Probabilidade de Eventos Dependentes
# Dado o nascimento de duas crianças:
# Qual a probabilidade de nascer duas meninas, sendo a mais velha uma menina (1/4 / 2/4) = 1/4 4/2 => 0,5
# Qual a probabilidade de nascer duas meninas, sendo qualquer das crianças menina (1/4 / 3/4) = 1/4 4/3 => 0,3

# %%
Probabilidade de Eventos Dependentes
Dado o nascimento de duas crianças:
Qual a probabilidade de nascer duas meninas, sendo a mais velha uma menina (1/4 / 2/4) = 1/4 4/2 => 0,5
Qual a probabilidade de nascer duas meninas, sendo qualquer das crianças menina (1/4 / 3/4) = 1/4 4/3 => 0,3

#probabilidade de eventos dependentes
both_girls = 0
older_girl = 0
either_girl = 0
random.seed(random.random())

for _ in range(10000):
    younger = random.choice(["boy", "girl"])
    older = random.choice(["boy", "girl"])
    if older == "girl":
        older_girl += 1
    if older == "girl" and younger == "girl":
        both_girls += 1
    if older == "girl" or younger == "girl":
        either_girl += 1

print ("P(both | older):", both_girls / older_girl)
print ("P(both | either): ", both_girls / either_girl)

# %%
y=[0.25, 0.5, 0.25] #probabilidade associada
x=[0, 1, 2] #evento

npa = np.asarray(y, dtype=np.float32)
print(npa.sum()) # soma da probabilidade de todos os eventos possíveis = 1

#Criando 3 axes - um para cada gráfico
#fig, ax_lst = plt.subplots(1, 2)
plt.plot(x,y,'ro')

plt.suptitle('Distribuição de probabilidade')

plt.show()
# Out:
# 1.0

# %%
op1=0
op2=0
op3=0

t = np.arange(0,1000)

for x in range(1000):
    ht1 = random.choice(["0", "1"])
    ht2 = random.choice(["0", "1"])
    if (ht1 == "0") & (ht2 == "0"):
        op1 += 1
        t[x]=0
    if (ht1 == "0") & (ht2 == "1"):
        op2 += 1
        t[x]=1
    if (ht1 == "1") & (ht2 == "0"):
        op2 += 1
        t[x]=1
    if (ht1 == "1") & (ht2 == "1"):
        op3 += 1
        t[x]=2
    

print(op1,op2,op3)
total=(op1+op2+op3)/1000
print(total)

y=[op1, op2, op3] #probabilidade associada
x=[0, 1, 2] #evento

npa = np.asarray(y, dtype=np.float32)
print(npa.sum()) # soma da probabilidade de todos os eventos possíveis = 1

#Criando 3 axes - um para cada gráfico
#fig, ax_lst = plt.subplots(1, 2)
plt.plot(x,y,'ro')

plt.suptitle('Distribuição de probabilidade')

plt.show()
# Out:
# 241 505 254
# 1.0
# 1000.0

# %%
print(t.shape)
t2=t[102:453]
print(t2.shape)

plt.hist(t2,3)

plt.suptitle('Distribuição de probabilidade')

plt.show()
# Out:
# (1000,)
# (351,)

# %%
data = np.random.uniform(0,10,1000) # 10 pontos entre 0 e 10 seguindo uma distribuição uniforme

#count, bins, ignored = plt.hist(data, 20, facecolor='green') 
#count, bins, ignored = plt.hist(data) 
#count = plt.hist(data) 

plt.hist(data,10) 

plt.xlabel('X~U[0,10]')
plt.ylabel('Frequência')
plt.title("Histograma da Distribuição Uniforme")
plt.axis([0, 10, 0, 100]) # x_start, x_end, y_start, y_end
plt.grid(True)

plt.show(block = False)

# %%
# distribuição uniforme

data = np.random.uniform(0,9,1000) # 10 pontos entre 0 e 10 seguindo uma distribuição uniforme

fig, ax_lst = plt.subplots(2, 1)

plt.ylabel('Frequência da Distribuição')
count, bins, ignored = ax_lst[0].hist(data, 10) 

ax_lst[1].plot(count)
ax_lst[1].axis([0, 10, 70, 130]) # x_start, x_end, y_start, y_end

plt.show()

# %%
# distribuição uniforme discreta

unifDisc = np.random.randint(10, size=1000)

fig, ax_lst = plt.subplots(2, 1)

plt.ylabel('Frequência da Distribuição')

count, bins, ignored = ax_lst[0].hist(unifDisc, 10) 

ax_lst[1].plot(count)

plt.show()

# %%
# distribuição normal

mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.default_rng().normal(mu, sigma, 1000)

fig, ax_lst = plt.subplots(2, 1)

plt.ylabel('Frequência da Distribuição')

count, bins, ignored = ax_lst[0].hist(s, 30) 

ax_lst[1].plot(count)

plt.show()

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.default_rng().normal(mu, sigma, 1000)

count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),linewidth=2, color='r')

plt.show()

# %%
from scipy.stats import binom

x = binom.rvs(n=5,p=0.8,size=10000)

plt.ylabel('Frequência da Distribuição')

count, bins, ignored = plt.hist(x, 30) 

plt.show()

# %%
from scipy.stats import bernoulli
x = bernoulli.rvs(size=1000,p=0.3)

#fig, ax_lst = plt.subplots(2, 1)

plt.ylabel('Frequência da Distribuição')

count, bins, ignored = plt.hist(x, 30) 


plt.show()

# %%
height = pd.read_csv('Aula 2.1.001 - Estatística/dados/heights.csv')
print(height.head())

diabete = pd.read_csv('Aula 2.1.001 - Estatística/dados/pima-indians-diabetes.data.csv')
print(diabete.head())

usaarrests = pd.read_csv('Aula 2.1.001 - Estatística/dados/USArrests.csv')
print(usaarrests.head())

births = pd.read_csv('Aula 2.1.001 - Estatística/dados/daily-total-female-births.csv')
print(births.head())

College = pd.read_csv('Aula 2.1.001 - Estatística/dados/College.csv')
print(College.head())

Auto = pd.read_csv('Aula 2.1.001 - Estatística/dados/Auto.csv')
print(Auto.head())
# Out:
#    HEIGHT  GENDER
# 0    56.0  Female
# 1    57.0  Female
# 2    58.0  Female
# 3    60.0  Female
# 4    60.0  Female
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Class
# 0                     0.627   50      1
# 1                     0.351   31      0
# 2                     0.672   32      1
# 3                     0.167   21      0
# 4                     2.288   33      1
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6
#          Date  Births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0   70        78       18.1           12    7041         60
# 1   29        30       12.2           16   10527         56
# 2   53        66       12.9           30    8735         54
# 3   92        97        7.7           37   19016         59
# 4   76        72       11.9            2   10922         15
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
from scipy import stats

x = stats.norm.rvs(loc=5, scale=3, size=100)
stat, pvalor = stats.shapiro(x)
print('Statistica=%.10f, p=%.10f' % (stat, pvalor))

alpha = 0.05

if pvalor > alpha:
    print('Similar a curva Gaussiana (falha para rejeitar H0)')
else:
    print('Não é similar a curva Gaussiana (rejeita H0)')
# Out:
# Statistica=0.9915452600, p=0.7873899937
# Similar a curva Gaussiana (falha para rejeitar H0)

# %%
from scipy.stats import shapiro
stat, pvalor = shapiro(height['HEIGHT'])

print('Statistica=%.10f, p=%.10f' % (stat, pvalor))

alpha = 0.05

if pvalor > alpha:
    print('Similar a curva Gaussiana (falha para rejeitar H0)')
else:
    print('Não é similar a curva Gaussiana (rejeita H0)')
# Out:
# Statistica=0.9599617720, p=0.0000000119
# Não é similar a curva Gaussiana (rejeita H0)

# %%
from scipy.stats import mannwhitneyu

#stat, p = mannwhitneyu(from_csv['Assault'], from_csv2['Assault'])
stat, p = mannwhitneyu(usaarrests['Assault'], usaarrests['Rape'])

print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Mesma distribuição (falha para rejeitar H0)')
else:
    print('distribuições diferentes')
# Out:
# stat=1.500, p=0.000
# distribuições diferentes

# %%
x1 = stats.norm.rvs(loc=5, scale=3, size=100)
x2 = stats.norm.rvs(loc=5, scale=3, size=100)

stat, p = mannwhitneyu(x1, x2)

print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Mesma distribuição (falha para rejeitar H0)')
else:
    print('distribuições diferentes')
# Out:
# stat=4911.000, p=0.414
# Mesma distribuição (falha para rejeitar H0)
