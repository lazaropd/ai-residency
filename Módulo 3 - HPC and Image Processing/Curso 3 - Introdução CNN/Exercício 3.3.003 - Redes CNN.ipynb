# %% [markdown]
# # Exercício 3:
# * Montar o ambiente para executar tensorflow com gpu (tensorflow-gpu): OK
# * Executar código do mnist: OK, executado no notebook da aula
# * Fazer teste com uma rede treinada (VGG16): OK, executado no notebook da aula
# * Utilizar a mesma topologia de rede neural usada para o problema minist, aplicando para o problema das abelhas
# * Compare o tempo de treino da rede neural CNN usando CPUxGPU

# %% [markdown]
# # Conclusões
# * os itens 1, 2 e 3 já havia feito durante a aula, funcionando corretamente
# * o uso da conv2d estava causando estouro de memória na GPU
#     * solução foi alterar a variável de ambiente os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# * usando a mesma topologia da MNIST para as abelhas mostrou desempenho ruim
#     * observamos overfitting antes da época 10, e acurácia final de apenas 0.26 na base de teste
#     * a base é altamente desbalanceada (as classes sicula e major por exemplo possuem apenas 10 exemplares)
#     * o número de amostras é bastante pequeno, uma estratégia de data augmentation poderia suprir classes pouco representadas
#     * o problema Abelhas é mais complexo, deveríamos rever a topologia
#     * vamos testar acrescentar dropout nas camadas fully connected
#     * vamos testar acrescentar BatchNormalisation nas camadas convolucionais
# * a adição de muitas novas camadas, e diversos mecanismos de regularização não resolveu o problema
#     * overfitting continua muito presente
#     * a adição de novas camadas não adicionou nenhuma melhoria significativa de performance
#     * vamos partir para a próxima abordagem, vamos tentar corrigir o tamanho da base de dados usando data augmentation
#     * em última análise, a causa do overfitting pode ser devido incapacidade da rede generalizar um dataset muito pequeno
#     * o overfitting foi controlado com a base aumentada e várias técnicas de regularização, porém ainda está bastante instável
# * removemos a categoria com muito pouco amostras e removemos algumas imagens outliers (sujas)
#     * as categorias sicura e major com apenas 10 imagens foram descartadas, assim como algumas imagens que estavam muito manchadas com fitas ou rasgadas
# * o tempo de treinamento para uma mesma rede foi 98% mais rápida usando a GPU, para diferentes valores de batch_size

# %% [markdown]
# ## Treino Abelhas

# %%
# criei uma classe para abstrair a inicialização dos workers, GPU/CPU, dataset e plots

from rubia_cnn import * 
from stridednet import *

# %% [markdown]
# ## Treino usando a base de imagens original

# %%
def extractInfo(name):
    category = name.split(' ')
    return category[0]

def createData(path, width, height, to_cat=False):
    X, y = [], []
    for p in os.listdir(path):
        category = p.split(".")[0]
        category = extractInfo(category)
        img_array = cv2.imread(os.path.join(path, p), cv2.IMREAD_GRAYSCALE)
        new_img_array = cv2.resize(img_array, dsize=(height, width))
        X.append(new_img_array)
        y.append(category)
    X = np.array(X)
    X = X.reshape((X.shape[0], height, width, 1))
    X = X.astype('float32') / 255
    y = np.array(y)
    if to_cat:
        le = LabelEncoder()
        yy = le.fit_transform(y)
        y = to_categorical(yy)
        decoder = lambda cat_code: le.inverse_transform(cat_code)
        return X, y, decoder, le.classes_
    return X, y, None, None


path = '/home/lazarop/Downloads/wingsEval'
width, height, depth = 80, 80, 1
X, y, decoder, classes = createData(path, width, height, to_cat=True)

# teste se o decoder está funcionando corretamente
print('Teste do decoder:', decoder([5, 6, 7]))
      
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    stratify=y, shuffle=True)
# Out:
# Teste do decoder: ['caucasica' 'cecropia' 'cypria']

# %% [markdown]
# ### Topologia MNIST

# %%
gpu = True
workers = 10
epochs = 200
batch_size = 256

k = cnn_keras(X=X_train, y=y_train, gpu=gpu, workers=workers)

opt = Adam(lr=1e-4, decay=1e-4/epochs)
reg = l2(0.0005)

model = StridedNetOne.build(width=width, height=height, depth=depth, 
                            classes=len(classes), reg=reg)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
model.summary()

print('\nTraining started: using ClassOne')
history = model.fit(k.X, k.y, epochs=epochs, batch_size=batch_size, verbose=0, 
                    validation_split=0.2, workers=k.workers, use_multiprocessing=k.multicore)
k.printHistory(history.history, metric='accuracy')

print('\nModel evaluation')
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
k.printPerformanceC(X_test, y_test, model=model)
# Out:
# Versions:
# Keras : 2.2.4-tf
# Tensorflow : 2.1.0
#
# GPU enabled!
# Number of workers adjusted to fit the GPUs available
# Using 1 GPU workers
# CPU test for EYE(10000):  0.26414918899536133
# GPU test for EYE(10000):  0.016208648681640625
# Multiprocessing status: False
#
# Neural network setup:
# X data shape:             (1292, 80, 80, 1)
# y data shape:             (1292, 23)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 39, 16)        160
# _________________________________________________________________
# activation (Activation)      (None, 39, 39, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 39, 39, 16)        64
# _________________________________________________________________
# dropout (Dropout)            (None, 39, 39, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 20, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 20, 20, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 20, 20, 32)        128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 20, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 23)                294423
# _________________________________________________________________
# activation_2 (Activation)    (None, 23)                0
# =================================================================
# Total params: 299,415
# Trainable params: 299,319
# Non-trainable params: 96
# _________________________________________________________________
#
# Training started: using ClassOne
#
# Performance (train/test): 1.00 / 0.28
# Model evaluation
# /home/lazarop/miniconda3/envs/tfgpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ACCURACY:  22.5 %

# %% [markdown]
# ## Otimização da topologia para combater o overfitting e aumentar acurácia

# %%
gpu = True
workers = 10
epochs = 200
batch_size = 256

k = cnn_keras(X=X_train, y=y_train, gpu=gpu, workers=workers)

opt = Adam(lr=1e-4, decay=1e-4/epochs)
reg = l2(0.0005)

model = StridedNetTwo.build(width=width, height=height, depth=depth, 
                            classes=len(classes), reg=reg)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
model.summary()

print('\nTraining started: using ClassTwo')
history = model.fit(k.X, k.y, epochs=epochs, batch_size=batch_size, verbose=0, 
                    validation_split=0.2, workers=k.workers, use_multiprocessing=k.multicore)
k.printHistory(history.history, metric='accuracy')

print('\nModel evaluation')
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
k.printPerformanceC(X_test, y_test, model=model)
# Out:
# Versions:
# Keras : 2.2.4-tf
# Tensorflow : 2.1.0
#
# GPU enabled!
# Number of workers adjusted to fit the GPUs available
# Using 1 GPU workers
# CPU test for EYE(10000):  0.26996445655822754
# GPU test for EYE(10000):  0.0005495548248291016
# Multiprocessing status: False
#
# Neural network setup:
# X data shape:             (1292, 80, 80, 1)
# y data shape:             (1292, 23)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 78, 78, 16)        160
# _________________________________________________________________
# activation (Activation)      (None, 78, 78, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 78, 78, 16)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 78, 78, 16)        272
# _________________________________________________________________
# activation_1 (Activation)    (None, 78, 78, 16)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 78, 78, 16)        64
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 39, 39, 16)        2320
# _________________________________________________________________
# activation_2 (Activation)    (None, 39, 39, 16)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 39, 39, 16)        64
# _________________________________________________________________
# dropout (Dropout)            (None, 39, 39, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 32)        4640
# _________________________________________________________________
# activation_3 (Activation)    (None, 20, 20, 32)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 20, 20, 32)        128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 20, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 23)                294423
# _________________________________________________________________
# activation_4 (Activation)    (None, 23)                0
# =================================================================
# Total params: 302,135
# Trainable params: 301,975
# Non-trainable params: 160
# _________________________________________________________________
#
# Training started: using ClassTwo
#
# Performance (train/test): 1.00 / 0.49
# Model evaluation
# /home/lazarop/miniconda3/envs/tfgpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ACCURACY:  35.2 %

# %%
gpu = True
workers = 10
epochs = 500
batch_size = 256

k = cnn_keras(X=X_train, y=y_train, gpu=gpu, workers=workers)

opt = Adam(lr=1e-4, decay=1e-4/epochs)
reg = l2(0.0005)

model = StridedNetFour.build(width=width, height=height, depth=depth, 
                            classes=len(classes), reg=reg)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
model.summary()

print('\nTraining started: using ClassFour')
history = model.fit(k.X, k.y, epochs=epochs, batch_size=batch_size, verbose=0, 
                    validation_split=0.2, workers=k.workers, use_multiprocessing=k.multicore)
k.printHistory(history.history, metric='accuracy')

print('\nModel evaluation')
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
k.printPerformanceC(X_test, y_test, model=model)
# Out:
# Versions:
# Keras : 2.2.4-tf
# Tensorflow : 2.1.0
#
# GPU enabled!
# Number of workers adjusted to fit the GPUs available
# Using 1 GPU workers
# CPU test for EYE(10000):  0.28142333030700684
# GPU test for EYE(10000):  0.011284589767456055
# Multiprocessing status: False
#
# Neural network setup:
# X data shape:             (1292, 80, 80, 1)
# y data shape:             (1292, 23)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 76, 76, 16)        416
# _________________________________________________________________
# activation (Activation)      (None, 76, 76, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 76, 76, 16)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 76, 76, 16)        272
# _________________________________________________________________
# activation_1 (Activation)    (None, 76, 76, 16)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 76, 76, 16)        64
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 38, 38, 16)        2320
# _________________________________________________________________
# activation_2 (Activation)    (None, 38, 38, 16)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 38, 38, 16)        64
# _________________________________________________________________
# dropout (Dropout)            (None, 38, 38, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 38, 38, 32)        4640
# _________________________________________________________________
# activation_3 (Activation)    (None, 38, 38, 32)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 38, 38, 32)        128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 38, 38, 32)        1056
# _________________________________________________________________
# activation_4 (Activation)    (None, 38, 38, 32)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 38, 38, 32)        128
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 19, 19, 32)        9248
# _________________________________________________________________
# activation_5 (Activation)    (None, 19, 19, 32)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 19, 19, 32)        128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19, 19, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 19, 19, 64)        18496
# _________________________________________________________________
# activation_6 (Activation)    (None, 19, 19, 64)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 19, 19, 64)        256
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# activation_7 (Activation)    (None, 10, 10, 64)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 10, 10, 64)        256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 184)               1177784
# _________________________________________________________________
# activation_8 (Activation)    (None, 184)               0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 184)               736
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 184)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 92)                17020
# _________________________________________________________________
# activation_9 (Activation)    (None, 92)                0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 92)                368
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 92)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 23)                2139
# _________________________________________________________________
# activation_10 (Activation)   (None, 23)                0
# =================================================================
# Total params: 1,272,511
# Trainable params: 1,271,415
# Non-trainable params: 1,096
# _________________________________________________________________
#
# Training started: using ClassFour
#
# Performance (train/test): 0.55 / 0.29
# Model evaluation
# /home/lazarop/miniconda3/envs/tfgpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ACCURACY:  29.0 %

# %% [markdown]
# # Data augmentation para aumentar o tamanho da base

# %%
import imutils

path = '/home/lazarop/Downloads/wingsEval/'
path_aug = '/home/lazarop/Downloads/wingsEvalAug/'

variations = 50 # for each input image
dim = 80 # dimensoes da imagem final

           
DATAGEN = ImageDataGenerator(
    rotation_range = 50,
    width_shift_range = 0.10,
    height_shift_range = 0.10,
    #shear_range = 0.05,
    zoom_range = 0.3,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'constant',
    cval = 255)

def generateImgs(path, path_aug, category, imgs, variations, dim):
    for img in imgs:
        image = cv2.imread(path + img, 0)
        x = img_to_array(image)
        x = x.reshape((1,) + x.shape)
        imageGen = DATAGEN.flow(x, batch_size=1, save_to_dir=path_aug, 
                                save_prefix=category, save_format='jpg')
        total = 0
        for new in imageGen:
            total += 1
            if total == variations:
                break
            
def cleanAug(path_aug):
    try:
        os.mkdir(path_aug)
    except:
        for item in os.listdir(path_aug):
            os.remove(path_aug + item)

def preprocessImgs(path_aug, dim):
    ksize = 7
    kernel = np.ones((ksize,ksize), np.uint8)
    for item in os.listdir(path_aug):
        image = cv2.imread(path_aug + item, 0)
        image = imutils.resize(image, width=dim)
        #image = cv2.erode(image, kernel, iterations=1)
        #image = cv2.blur(image, ksize=(ksize, ksize))
        #_, thresh = cv2.threshold(image, 220, 255, cv2.THRESH_BINARY)
        #thresh = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)
        #thresh = cv2.threshold(image, 80, 90, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
        #image = cv2.bitwise_and(image, image, mask=thresh)
        #image[thresh==0] = 255
        #_, image = cv2.threshold(image, 60, 120, cv2.THRESH_BINARY)
        #image = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2)
        #image = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)
        #image = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)
        #image = cv2.erode(image, kernel, iterations=1)
        #image = cv2.dilate(image, kernel, iterations=1)
        cv2.imwrite(path_aug + item, image)
        if random.random() < 0.001: # random select a few images to plot: use this to adjust the filters below
            plt.imshow(image, cmap='gray')
            plt.axis('off')
            plt.show()
        
def getImgs(path, path_aug, variations, dim, gen=True):
    if gen:
        cleanAug(path_aug)
        files = []
        for item in os.listdir(path):
            files.append(item)
        df = pd.DataFrame({'file': files})
        df['category'] = df.file.apply(lambda x: x.split('.')[0].split(' ')[0])
        #print(df.groupby('category').count())
        smallest = int(df.groupby('category').count().min())
        for category in df.category.unique():
            raw_samples = df.loc[df.category==category]['file'].sample(smallest).tolist()
            generateImgs(path, path_aug, category, raw_samples, variations, dim)
        preprocessImgs(path_aug, dim)    

        
getImgs(path, path_aug, variations, dim, gen=True)

# %%
def extractInfoAug(name):
    category = name.split('_')
    return category[0]

def createDataAug(path, width, height, to_cat=False):
    X, y = [], []
    for p in os.listdir(path):
        category = p.split(".")[0]
        category = extractInfoAug(category)
        img_array = cv2.imread(os.path.join(path, p), cv2.IMREAD_GRAYSCALE)
        new_img_array = cv2.resize(img_array, dsize=(height, width))
        X.append(new_img_array)
        y.append(category)
    X = np.array(X)
    X = X.reshape((X.shape[0], height, width, 1))
    X = X.astype('float32') / 255
    y = np.array(y)
    if to_cat:
        le = LabelEncoder()
        yy = le.fit_transform(y)
        y = to_categorical(yy)
        decoder = lambda cat_code: le.inverse_transform(cat_code)
        return X, y, decoder, le.classes_
    return X, y, None, None


pathAug = '/home/lazarop/Downloads/wingsEvalAug'
width, height, depth = 80, 80, 1
X, y, decoder, classes = createDataAug(pathAug, width, height, to_cat=True)

# teste se o decoder está funcionando corretamente
print('Teste do decoder:', decoder([5, 6, 7]))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    stratify=y, shuffle=True)
# Out:
# Teste do decoder: ['caucasica' 'cecropia' 'cypria']

# %%
gpu = True
workers = 10
epochs = 500
batch_size = 128
start = time.time()

k = cnn_keras(X=X_train, y=y_train, gpu=gpu, workers=workers)

opt = Adam(lr=1e-4, decay=1e-4/epochs)
reg = l2(0.0005)

model = StridedNetSix.build(width=width, height=height, depth=depth, 
                            classes=len(classes), reg=reg)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
model.summary()

print('\nTraining started: using ClassSix')
history = model.fit(k.X, k.y, epochs=epochs, batch_size=batch_size, verbose=1, 
                    validation_split=0.2, workers=k.workers, use_multiprocessing=k.multicore)
k.printHistory(history.history, metric='accuracy')

print('\nModel evaluation')
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
k.printPerformanceC(X_test, y_test, model=model)

et = time.time()-start
print('Elapsed time: %d seg (%.1f epochs/minute):' %(et, (60*epochs/et)))
# Out:
# Versions:
# Keras : 2.2.4-tf
# Tensorflow : 2.1.0
#
# GPU enabled!
# Number of workers adjusted to fit the GPUs available
# Using 1 GPU workers
# CPU test for EYE(10000):  0.27486085891723633
# GPU test for EYE(10000):  0.016629457473754883
# Multiprocessing status: False
#
# Neural network setup:
# X data shape:             (15008, 80, 80, 1)
# y data shape:             (15008, 23)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 74, 74, 16)        800
# _________________________________________________________________
# activation (Activation)      (None, 74, 74, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 74, 74, 16)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 74, 74, 16)        272
# _________________________________________________________________
# activation_1 (Activation)    (None, 74, 74, 16)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 74, 74, 16)        64
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 16)        2320
# _________________________________________________________________
# activation_2 (Activation)    (None, 37, 37, 16)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 37, 37, 16)        64
# _________________________________________________________________
# dropout (Dropout)            (None, 37, 37, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 37, 37, 32)        4640
# _________________________________________________________________
# activation_3 (Activation)    (None, 37, 37, 32)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 37, 37, 32)        128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 32)        1056
# _________________________________________________________________
# activation_4 (Activation)    (None, 37, 37, 32)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 37, 37, 32)        128
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 19, 19, 32)        9248
# _________________________________________________________________
# activation_5 (Activation)    (None, 19, 19, 32)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 19, 19, 32)        128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19, 19, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 19, 19, 64)        18496
# _________________________________________________________________
# activation_6 (Activation)    (None, 19, 19, 64)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 19, 19, 64)        256
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 19, 19, 64)        4160
# _________________________________________________________________
# activation_7 (Activation)    (None, 19, 19, 64)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 19, 19, 64)        256
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# activation_8 (Activation)    (None, 10, 10, 64)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 10, 10, 64)        256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_9 (Activation)    (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 10, 10, 128)       512
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 10, 10, 128)       16512
# _________________________________________________________________
# activation_10 (Activation)   (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 5, 128)         147584
# _________________________________________________________________
# activation_11 (Activation)   (None, 5, 5, 128)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 5, 5, 128)         512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 5, 5, 256)         295168
# _________________________________________________________________
# activation_12 (Activation)   (None, 5, 5, 256)         0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 5, 5, 256)         1024
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 5, 5, 256)         590080
# _________________________________________________________________
# activation_13 (Activation)   (None, 5, 5, 256)         0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 5, 5, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 5, 5, 512)         1180160
# _________________________________________________________________
# activation_14 (Activation)   (None, 5, 5, 512)         0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 3, 3, 512)         2359808
# _________________________________________________________________
# activation_15 (Activation)   (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 368)               1696112
# _________________________________________________________________
# activation_16 (Activation)   (None, 368)               0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 368)               1472
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 368)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 92)                33948
# _________________________________________________________________
# activation_17 (Activation)   (None, 92)                0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 92)                368
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 92)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 23)                2139
# _________________________________________________________________
# activation_18 (Activation)   (None, 23)                0
# =================================================================
# Total params: 6,484,151
# Trainable params: 6,478,719
# Non-trainable params: 5,432
# _________________________________________________________________
#
# Training started: using ClassSix
# Train on 12006 samples, validate on 3002 samples
# Epoch 1/500
# 12006/12006 [==============================] - 10s 819us/sample - loss: 6.3580 - accuracy: 0.0591 - val_loss: 5.6239 - val_accuracy: 0.0443
# Epoch 2/500
# 12006/12006 [==============================] - 8s 651us/sample - loss: 6.0097 - accuracy: 0.0774 - val_loss: 6.1187 - val_accuracy: 0.0433
# Epoch 3/500
# 12006/12006 [==============================] - 8s 627us/sample - loss: 5.8339 - accuracy: 0.0845 - val_loss: 6.7795 - val_accuracy: 0.0433
# Epoch 4/500
# 12006/12006 [==============================] - 8s 633us/sample - loss: 5.7015 - accuracy: 0.0848 - val_loss: 6.9362 - val_accuracy: 0.0440
# Epoch 5/500
# 12006/12006 [==============================] - 8s 636us/sample - loss: 5.6099 - accuracy: 0.0920 - val_loss: 6.7560 - val_accuracy: 0.0436
# Epoch 6/500
# 12006/12006 [==============================] - 8s 637us/sample - loss: 5.5354 - accuracy: 0.0990 - val_loss: 6.6094 - val_accuracy: 0.0436
# Epoch 7/500
# 12006/12006 [==============================] - 8s 639us/sample - loss: 5.4399 - accuracy: 0.1089 - val_loss: 6.4693 - val_accuracy: 0.0436
# Epoch 8/500
# 12006/12006 [==============================] - 8s 642us/sample - loss: 5.3864 - accuracy: 0.1095 - val_loss: 6.3065 - val_accuracy: 0.0436
# Epoch 9/500
# 12006/12006 [==============================] - 8s 643us/sample - loss: 5.2984 - accuracy: 0.1235 - val_loss: 6.0544 - val_accuracy: 0.0473
# Epoch 10/500
# 12006/12006 [==============================] - 8s 645us/sample - loss: 5.2307 - accuracy: 0.1315 - val_loss: 5.9209 - val_accuracy: 0.0606
# Epoch 11/500
# 12006/12006 [==============================] - 8s 645us/sample - loss: 5.1624 - accuracy: 0.1431 - val_loss: 6.2119 - val_accuracy: 0.0623
# Epoch 12/500
# 12006/12006 [==============================] - 8s 645us/sample - loss: 5.0543 - accuracy: 0.1588 - val_loss: 5.8997 - val_accuracy: 0.0963
# Epoch 13/500
# 12006/12006 [==============================] - 8s 653us/sample - loss: 5.0154 - accuracy: 0.1698 - val_loss: 5.7138 - val_accuracy: 0.0973
# Epoch 14/500
# 12006/12006 [==============================] - 8s 666us/sample - loss: 4.9268 - accuracy: 0.1798 - val_loss: 5.8322 - val_accuracy: 0.0846
500
# 12006/12006 [==============================] - 8s 654us/sample - loss: 1.9834 - accuracy: 0.7817 - val_loss: 2.4621 - val_accuracy: 0.6489
# Epoch 85/500
# 12006/12006 [==============================] - 8s 655us/sample - loss: 1.9774 - accuracy: 0.7834 - val_loss: 3.5853 - val_accuracy: 0.4264
# Epoch 86/500
# 12006/12006 [==============================] - 8s 654us/sample - loss: 1.9271 - accuracy: 0.7972 - val_loss: 2.5477 - val_accuracy: 0.6266
# Epoch 87/500
# 12006/12006 [==============================] - 8s 655us/sample - loss: 1.8989 - accuracy: 0.8068 - val_loss: 2.4589 - val_accuracy: 0.6332
# Epoch 88/500
# 12006/12006 [==============================] - 8s 655us/sample - loss: 1.8776 - accuracy: 0.8153 - val_loss: 2.4478 - val_accuracy: 0.6406
# Epoch 89/500
# 12006/12006 [==============================] - 8s 655us/sample - loss: 1.8414 - accuracy: 0.8235 - val_loss: 2.8664 - val_accuracy: 0.5383
# Epoch 90/500
# 12006/12006 [==============================] - 8s 654us/sample - loss: 1.8202 - accuracy: 0.8293 - val_loss: 2.7053 - val_accuracy: 0.5769
# Epoch 91/500
# 12006/12006 [==============================] - 8s 655us/sample - loss: 1.8079 - accuracy: 0.8308 - val_loss: 2.5451 - val_accuracy: 0.6169
# Epoch 92/500
# 12006/12006 [==============================] - 8s 654us/sample - loss: 1.7750 - accuracy: 0.8387 - val_loss: 2.6826 - val_accuracy: 0.5829
# Epoch 93/500
# 12006/12006 [==============================] - 8s 655us/sample - loss: 1.7702 - accuracy: 0.8359 - val_loss: 2.1326 - val_accuracy: 0.7169
# Epoch 94/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 1.7462 - accuracy: 0.8392 - val_loss: 2.0045 - val_accuracy: 0.7548
# Epoch 95/500
# 12006/12006 [==============================] - 8s 654us/sample - loss: 1.7346 - accuracy: 0.8473 - val_loss: 2.5415 - val_accuracy: 0.6116
# Epoch 96/500
# 12006/12006 [==============================] - 8s 655us/sample - loss: 1.6962 - accuracy: 0.8544 - val_loss: 2.0495 - val_accuracy: 0.7392
# Epoch 97/500
# 12006/12006 [==============================] - 8s 653us/sample - loss: 1.6539 - accuracy: 0.8690 - val_loss: 2.2070 - val_accuracy: 0.7015
# Epoch 98/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 1.6431 - accuracy: 0.8691 - val_loss: 1.8472 - val_accuracy: 0.8001
# Epoch 99/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 1.6127 - accuracy: 0.8804 - val_loss: 3.7193 - val_accuracy: 0.4780
# Epoch 100/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 1.6084 - accuracy: 0.8761 - val_loss: 2.7016 - val_accuracy: 0.5989
# Epoch 101/500
# 12006/12006 [==============================] - 8s 655us/sample - loss: 1.5938 - accuracy: 0.8789 - val_loss: 2.1892 - val_accuracy: 0.7152
# Epoch 102/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 1.5694 - accuracy: 0.8818 - val_loss: 2.8461 - val_accuracy: 0.5913
# Epoch 103/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 1.5478 - accuracy: 0.8904 - val_loss: 2.5199 - val_accuracy: 0.6416
# Epoch 104/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 1.5341 - accuracy: 0.8894 - val_loss: 2.6854 - val_accuracy: 0.6243
# Epoch 105/500
# 12006/12006 [==============================] - 8s 655us/sample - loss: 1.5246 - accuracy: 0.8936 - val_loss: 2.0282 - val_accuracy: 0.7508
# Epoch 106/500
# 12006/12006 [==============================] - 8s 654us/sample - loss: 1.5084 - accuracy: 0.8995 - val_loss: 2.1820 - val_accuracy: 0.7029
# Epoch 107/500
# 12006/12006 [==============================] - 8s 654us/sample - loss: 1.4928 - accuracy: 0.9019 - val_loss: 1.7902 - val_accuracy: 0.8068
# Epoch 108/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 1.4695 - accuracy: 0.9044 - val_loss: 3.1405 - val_accuracy: 0.5296
# Epoch 109/500
# 12006/12006 [==============================] - 8s 654us/sample - loss: 1.4566 - accuracy: 0.9117 - val_loss: 2.6521 - val_accuracy: 0.6223
# Epoch 110/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 1.4253 - accuracy: 0.9149 - val_loss: 2.9284 - val_accuracy: 0.5843
# Epoch 111/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 1.4186 - accuracy: 0.9172 - val_loss: 2.7520 - val_accuracy: 0.5989
# Epoch 112/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 1.4034 - accuracy: 0.9211 - val_loss: 2.8535 - val_accuracy: 0.5839
# Epoch 113/500
# 12006/12006 [==============================] - 8s 655us/sample - loss: 1
500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.9883 - accuracy: 0.9659 - val_loss: 2.1377 - val_accuracy: 0.7342
# Epoch 175/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.9712 - accuracy: 0.9699 - val_loss: 3.6137 - val_accuracy: 0.5250
# Epoch 176/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 0.9756 - accuracy: 0.9693 - val_loss: 2.0566 - val_accuracy: 0.7508
# Epoch 177/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.9508 - accuracy: 0.9735 - val_loss: 2.9751 - val_accuracy: 0.6226
# Epoch 178/500
# 12006/12006 [==============================] - 8s 659us/sample - loss: 0.9476 - accuracy: 0.9744 - val_loss: 2.2825 - val_accuracy: 0.7092
# Epoch 179/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 0.9555 - accuracy: 0.9714 - val_loss: 1.7919 - val_accuracy: 0.7901
# Epoch 180/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.9605 - accuracy: 0.9689 - val_loss: 1.8538 - val_accuracy: 0.7775
# Epoch 181/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.9366 - accuracy: 0.9748 - val_loss: 2.1432 - val_accuracy: 0.7245
# Epoch 182/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 0.9438 - accuracy: 0.9709 - val_loss: 1.9700 - val_accuracy: 0.7462
# Epoch 183/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 0.9453 - accuracy: 0.9715 - val_loss: 1.8451 - val_accuracy: 0.7708
# Epoch 184/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 0.9300 - accuracy: 0.9736 - val_loss: 3.5523 - val_accuracy: 0.5223
# Epoch 185/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.9384 - accuracy: 0.9707 - val_loss: 1.5201 - val_accuracy: 0.8418
# Epoch 186/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 0.9111 - accuracy: 0.9774 - val_loss: 2.0801 - val_accuracy: 0.7322
# Epoch 187/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 0.9103 - accuracy: 0.9768 - val_loss: 2.0516 - val_accuracy: 0.7375
# Epoch 188/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 0.9173 - accuracy: 0.9734 - val_loss: 1.7666 - val_accuracy: 0.7861
# Epoch 189/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.9006 - accuracy: 0.9778 - val_loss: 1.6933 - val_accuracy: 0.8025
# Epoch 190/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.9123 - accuracy: 0.9723 - val_loss: 1.6895 - val_accuracy: 0.8031
# Epoch 191/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.9086 - accuracy: 0.9746 - val_loss: 1.5130 - val_accuracy: 0.8344
# Epoch 192/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.9042 - accuracy: 0.9738 - val_loss: 3.1919 - val_accuracy: 0.5666
# Epoch 193/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.8946 - accuracy: 0.9753 - val_loss: 4.4778 - val_accuracy: 0.4657
# Epoch 194/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.8626 - accuracy: 0.9829 - val_loss: 1.5478 - val_accuracy: 0.8271
# Epoch 195/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 0.8839 - accuracy: 0.9772 - val_loss: 2.3970 - val_accuracy: 0.6935
# Epoch 196/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 0.8720 - accuracy: 0.9783 - val_loss: 2.1161 - val_accuracy: 0.7222
# Epoch 197/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.8789 - accuracy: 0.9765 - val_loss: 1.4368 - val_accuracy: 0.8564
# Epoch 198/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 0.8718 - accuracy: 0.9778 - val_loss: 1.5877 - val_accuracy: 0.8235
# Epoch 199/500
# 12006/12006 [==============================] - 8s 653us/sample - loss: 0.8650 - accuracy: 0.9766 - val_loss: 1.7342 - val_accuracy: 0.7821
# Epoch 200/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 0.8636 - accuracy: 0.9775 - val_loss: 1.8170 - val_accuracy: 0.7815
# Epoch 201/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 0.8585 - accuracy: 0.9787 - val_loss: 1.4424 - val_accuracy: 0.8471
# Epoch 202/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.8641 - accuracy: 0.9748 - val_loss: 1.7755 - val_accuracy: 0.7898
# Epoch 203/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.8738 - accuracy: 0.9723 - val_loss: 2.3017 - val_accuracy: 0.6842
# Epoch 204/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 0
500
# 12006/12006 [==============================] - 8s 659us/sample - loss: 0.4230 - accuracy: 0.9898 - val_loss: 4.2737 - val_accuracy: 0.4554
# Epoch 484/500
# 12006/12006 [==============================] - 8s 655us/sample - loss: 0.4052 - accuracy: 0.9937 - val_loss: 1.0604 - val_accuracy: 0.8588
# Epoch 485/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 0.4135 - accuracy: 0.9913 - val_loss: 2.3291 - val_accuracy: 0.6759
# Epoch 486/500
# 12006/12006 [==============================] - 8s 660us/sample - loss: 0.4191 - accuracy: 0.9874 - val_loss: 2.2102 - val_accuracy: 0.6889
# Epoch 487/500
# 12006/12006 [==============================] - 8s 660us/sample - loss: 0.4280 - accuracy: 0.9868 - val_loss: 5.4024 - val_accuracy: 0.3378
# Epoch 488/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.4304 - accuracy: 0.9867 - val_loss: 1.0792 - val_accuracy: 0.8641
# Epoch 489/500
# 12006/12006 [==============================] - 8s 659us/sample - loss: 0.4273 - accuracy: 0.9870 - val_loss: 3.1907 - val_accuracy: 0.5640
# Epoch 490/500
# 12006/12006 [==============================] - 8s 659us/sample - loss: 0.4124 - accuracy: 0.9903 - val_loss: 1.8209 - val_accuracy: 0.7332
# Epoch 491/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.4244 - accuracy: 0.9879 - val_loss: 1.4089 - val_accuracy: 0.7995
# Epoch 492/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 0.4229 - accuracy: 0.9881 - val_loss: 1.3392 - val_accuracy: 0.8264
# Epoch 493/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.4177 - accuracy: 0.9898 - val_loss: 3.2964 - val_accuracy: 0.5600
# Epoch 494/500
# 12006/12006 [==============================] - 8s 659us/sample - loss: 0.4154 - accuracy: 0.9903 - val_loss: 3.1176 - val_accuracy: 0.5536
# Epoch 495/500
# 12006/12006 [==============================] - 8s 657us/sample - loss: 0.4108 - accuracy: 0.9900 - val_loss: 1.1989 - val_accuracy: 0.8378
# Epoch 496/500
# 12006/12006 [==============================] - 8s 658us/sample - loss: 0.4070 - accuracy: 0.9916 - val_loss: 1.6559 - val_accuracy: 0.7592
# Epoch 497/500
# 12006/12006 [==============================] - 8s 659us/sample - loss: 0.4107 - accuracy: 0.9911 - val_loss: 4.6313 - val_accuracy: 0.4370
# Epoch 498/500
# 12006/12006 [==============================] - 8s 660us/sample - loss: 0.4087 - accuracy: 0.9906 - val_loss: 2.6115 - val_accuracy: 0.6326
# Epoch 499/500
# 12006/12006 [==============================] - 8s 656us/sample - loss: 0.3996 - accuracy: 0.9929 - val_loss: 1.4148 - val_accuracy: 0.7928
# Epoch 500/500
# 12006/12006 [==============================] - 8s 659us/sample - loss: 0.4069 - accuracy: 0.9906 - val_loss: 3.0648 - val_accuracy: 0.5763
#
# Performance (train/test): 0.99 / 0.58
# Model evaluation
# ACCURACY:  57.9 %
# Elapsed time: 3983 seg (7.5 epochs/minute):

# %% [markdown]
# ## Comparação GPU x CPU

# %%
def extractInfo(name):
    category = name.split(' ')
    return category[0]

def createData(path, size, to_cat=False):
    X, y = [], []
    for p in os.listdir(path):
        category = p.split(".")[0]
        category = extractInfo(category)
        img_array = cv2.imread(os.path.join(path, p), cv2.IMREAD_GRAYSCALE)
        new_img_array = cv2.resize(img_array, dsize=(size, size))
        X.append(new_img_array)
        y.append(category)
    X = np.array(X)
    X = X.reshape((X.shape[0], size, size, 1))
    X = X.astype('float32') / 255
    y = np.array(y)
    if to_cat:
        le = LabelEncoder()
        yy = le.fit_transform(y)
        y = to_categorical(yy)
    decoder = lambda cat_code: le.inverse_transform(cat_code)
    return X, y, decoder

path = '/home/lazarop/Downloads/wingsEval'
X, y, decoder = createData(path, 80, to_cat=True)

# teste se o decoder está funcionando corretamente
decoder([5, 6, 7])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
input_dim = (80, 80, 1)
output_dim = 23

kernel0 = 7
kerneli = 3
conv = 32
drop = 0.5

bench = []

epochs = 2
gpu = False
batch_size = 256

workers = 10
start = time.time()
k = cnn_keras(X=X_train, y=y_train, gpu=gpu, workers=workers)
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_dim))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(output_dim, activation='softmax'))
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(k.X, k.y, epochs=100, batch_size=batch_size, verbose=0, validation_split=0.2, 
      shuffle=True, workers=k.workers, use_multiprocessing=k.multicore)
print('\nModel evaluation')
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
bench.append([gpu, workers, batch_size, epochs, time.time()-start, test_acc])
# Out:
# Versions:
# Keras : 2.2.4-tf
# Tensorflow : 2.1.0
#
# GPU disabled!
# Using 10 CPU workers
# Multiprocessing status: True
#
# Neural network setup:
# X data shape:             (1292, 80, 80, 1)
# y data shape:             (1292, 23)
#
# Model evaluation

# %%
gpu = True
workers = 1
for batch_size in [16, 32, 64, 128, 256]:
    start = time.time()
    try:
        del k
    except:
        pass
    k = cnn_keras(X=X_train, y=y_train, gpu=gpu, workers=workers)
    history = model.fit(k.X, k.y, epochs=epochs, batch_size=batch_size, verbose=0, validation_split=0.2, 
          shuffle=True, workers=k.workers, use_multiprocessing=k.multicore)
    print('\nModel evaluation')
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
    bench.append([gpu, workers, batch_size, epochs, time.time()-start, test_acc])
# Out:
# Versions:
# Keras : 2.2.4-tf
# Tensorflow : 2.1.0
#
# GPU was not found. Using CPU instead!
# Multiprocessing status: False
#
# Neural network setup:
# X data shape:             (1292, 80, 80, 1)
# y data shape:             (1292, 23)
#
# Model evaluation
#
# Versions:
# Keras : 2.2.4-tf
# Tensorflow : 2.1.0
#
# GPU was not found. Using CPU instead!
# Multiprocessing status: False
#
# Neural network setup:
# X data shape:             (1292, 80, 80, 1)
# y data shape:             (1292, 23)
#
# Model evaluation
#
# Versions:
# Keras : 2.2.4-tf
# Tensorflow : 2.1.0
#
# GPU was not found. Using CPU instead!
# Multiprocessing status: False
#
# Neural network setup:
# X data shape:             (1292, 80, 80, 1)
# y data shape:             (1292, 23)
#
# Model evaluation
#
# Versions:
# Keras : 2.2.4-tf
# Tensorflow : 2.1.0
#
# GPU was not found. Using CPU instead!
# Multiprocessing status: False
#
# Neural network setup:
# X data shape:             (1292, 80, 80, 1)
# y data shape:             (1292, 23)
#
# Model evaluation
#
# Versions:
# Keras : 2.2.4-tf
# Tensorflow : 2.1.0
#
# GPU was not found. Using CPU instead!
# Multiprocessing status: False
#
# Neural network setup:
# X data shape:             (1292, 80, 80, 1)
# y data shape:             (1292, 23)
#
# Model evaluation

# %%
df_bench = pd.DataFrame(bench)
df_bench.columns = ['GPU', 'Workers', 'Batch Size', 'Epochs', 'Elapsed Time', 'Accuracy']
df_bench
# Out:
#      GPU  Workers  Batch Size  Epochs  Elapsed Time  Accuracy
# 0  False       10         256       2     91.024204  0.216049
# 1   True        1          16       2      2.376423  0.268519
# 2   True        1          32       2      2.009781  0.253086
# 3   True        1          64       2      2.077269  0.206790
# 4   True        1         128       2      2.029579  0.237654
# 5   True        1         256       2      2.011888  0.219136
