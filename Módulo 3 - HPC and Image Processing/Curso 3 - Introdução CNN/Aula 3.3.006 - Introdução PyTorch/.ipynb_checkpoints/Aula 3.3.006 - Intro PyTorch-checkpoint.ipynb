# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from torch.utils.data import Dataset, DataLoader, random_split

from torch import Tensor

from torch.nn import Linear, Conv2d, MaxPool2d
from torch.nn import ReLU
from torch.nn import Sigmoid, Softmax
from torch.nn import Module

from torch.nn import BCELoss, CrossEntropyLoss, MSELoss
from torch.nn.init import kaiming_uniform_, xavier_uniform_
from torch.optim import SGD

from torchvision.transforms import Compose, ToTensor, Normalize
from torchvision.datasets import ImageFolder

import utils

# %% [markdown]
# ## Dataset Ionosphere
# * Dataset para prever se existe uma estrutura na atmosfera ou se não de acordo com retornos de um radar (Ionosphere Dataset Description)
# * Y categorias: b (bad) ou g (good)

# %%
def loadIonosphere():
    path = '../dataset/ionosphere.csv'
    getter = lambda x: 1 if x == 'g' else 0
    df = pd.read_csv(path)
    print('Data shape:', df.shape)
    print('Variables:', df.columns)
    df['class'] = df['class'].apply(getter)
    return df

df = loadIonosphere()
df.describe().T
# Out:
# Data shape: (351, 35)
# Variables: Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        'a11', 'a12', 'a13', 'a14', 'a15', 'a16', 'a17', 'a18', 'a19', 'a20',
#        'a21', 'a22', 'a23', 'a24', 'a25', 'a26', 'a27', 'a28', 'a29', 'a30',
#        'a31', 'a32', 'a33', 'a34', 'class'],
#       dtype='object')
#        count      mean       std  min       25%      50%       75%  max
# a01    351.0  0.891738  0.311155  0.0  1.000000  1.00000  1.000000  1.0
# a02    351.0  0.000000  0.000000  0.0  0.000000  0.00000  0.000000  0.0
# a03    351.0  0.641342  0.497708 -1.0  0.472135  0.87111  1.000000  1.0
# a04    351.0  0.044372  0.441435 -1.0 -0.064735  0.01631  0.194185  1.0
# a05    351.0  0.601068  0.519862 -1.0  0.412660  0.80920  1.000000  1.0
# a06    351.0  0.115889  0.460810 -1.0 -0.024795  0.02280  0.334655  1.0
# a07    351.0  0.550095  0.492654 -1.0  0.211310  0.72873  0.969240  1.0
# a08    351.0  0.119360  0.520750 -1.0 -0.054840  0.01471  0.445675  1.0
# a09    351.0  0.511848  0.507066 -1.0  0.087110  0.68421  0.953240  1.0
# a10    351.0  0.181345  0.483851 -1.0 -0.048075  0.01829  0.534195  1.0
# a11    351.0  0.476183  0.563496 -1.0  0.021120  0.66798  0.957895  1.0
# a12    351.0  0.155040  0.494817 -1.0 -0.065265  0.02825  0.482375  1.0
# a13    351.0  0.400801  0.622186 -1.0  0.000000  0.64407  0.955505  1.0
# a14    351.0  0.093414  0.494873 -1.0 -0.073725  0.03027  0.374860  1.0
# a15    351.0  0.344159  0.652828 -1.0  0.000000  0.60194  0.919330  1.0
# a16    351.0  0.071132  0.458371 -1.0 -0.081705  0.00000  0.308975  1.0
# a17    351.0  0.381949  0.618020 -1.0  0.000000  0.59091  0.935705  1.0
# a18    351.0 -0.003617  0.496762 -1.0 -0.225690  0.00000  0.195285  1.0
# a19    351.0  0.359390  0.626267 -1.0  0.000000  0.57619  0.899265  1.0
# a20    351.0 -0.024025  0.519076 -1.0 -0.234670  0.00000  0.134370  1.0
# a21    351.0  0.336695  0.609828 -1.0  0.000000  0.49909  0.894865  1.0
# a22    351.0  0.008296  0.518166 -1.0 -0.243870  0.00000  0.188760  1.0
# a23    351.0  0.362475  0.603767 -1.0  0.000000  0.53176  0.911235  1.0
# a24    351.0 -0.057406  0.527456 -1.0 -0.366885  0.00000  0.164630  1.0
# a25    351.0  0.396135  0.578451 -1.0  0.000000  0.55389  0.905240  1.0
# a26    351.0 -0.071187  0.508495 -1.0 -0.332390 -0.01505  0.156765  1.0
# a27    351.0  0.541641  0.516205 -1.0  0.286435  0.70824  0.999945  1.0
# a28    351.0 -0.069538  0.550025 -1.0 -0.443165 -0.01769  0.153535  1.0
# a29    351.0  0.378445  0.575886 -1.0  0.000000  0.49664  0.883465  1.0
# a30    351.0 -0.027907  0.507974 -1.0 -0.236885  0.00000  0.154075  1.0
# a31    351.0  0.352514  0.571483 -1.0  0.000000  0.44277  0.857620  1.0
# a32    351.0 -0.003794  0.513574 -1.0 -0.242595  0.00000  0.200120  1.0
# a33    351.0  0.349364  0.522663 -1.0  0.000000  0.40956  0.813765  1.0
# a34    351.0  0.014480  0.468337 -1.0 -0.165350  0.00000  0.171660  1.0
# class  351.0  0.641026  0.480384  0.0  0.000000  1.00000  1.000000  1.0

# %% [markdown]
# ## Dataset Transport

# %%
# Usado apenas na primeira vez para codificar os dados originais do parceiro
preprocess = False

if preprocess:
    def loadTransport():
        le, lev = preprocessing.LabelEncoder(), preprocessing.LabelEncoder()
        df = pd.read_csv('../dataset/transport.csv')
        df["class"] = le.fit_transform(df["clas_score_geral"])
        removable = ['dia','id_uo_vei','inicio_vigencia','fim_vigencia','inicio_logradouro','processamento',
                     'fim_logradouro','final_hodometro','gps_invalido_consumo','vei_marca','vei_modelo',
                     'vei_ano','clas_score_geral']
        nulled = ['tempo_freio_motor','tempo_batendo_transmissao','qtd_motorista_ausente','qtd_sem_cinto',
                  'qtd_camera_obstruida','tempo_rpm_faixa_3','qtd_manuseio_celular','qtd_fadiga_motorista', 
                  'qtd_distracao_motorista','qtd_uso_cigarro','qtd_distancia_perigosa','qtd_diagnostico_obd', 
                  'qtd_possivel_colisao']
        df.drop(removable, axis=1, inplace=True)
        df.drop(nulled, axis=1, inplace=True)
        df.id_motorista.fillna(0, inplace=True)
        df.id_uo_motorista.fillna(0, inplace=True)
        df.vei_tipo.fillna('', inplace=True)
        df["vei_tipo"] = lev.fit_transform(df["vei_tipo"])
        print('Data shape:', df.shape)
        print('Variables:', df.columns)
        cols = []
        for i, col in enumerate(df.columns):
            if i == len(df.columns)-1:
                cols.append('class')
            else:
                name = ''.join([l[0] for l in col.split('_')])
                scaler = MinMaxScaler()
                df[col] = scaler.fit_transform(df[[col]])
                cols.append(name)
        df.columns = cols
        df.to_csv('dataset/transport.csv', index=False)
        return df
    
else:
    def loadTransport():
        df = pd.read_csv('../dataset/transport.csv')
        print('Data shape:', df.shape)
        print('Variables:', df.columns)
        return df


df = loadTransport()
df.describe().T
# Out:
# Data shape: (56424, 45)
# Variables: Index(['iv', 'im', 'ium', 'dp', 'qc', 'qa', 'qf', 'qt', 'qb', 'tb', 'qmo',
#        'tmo', 'qrf1', 'qvf1', 'qvf2', 'qvf3', 'tvf1', 'tvf2', 'tvf3', 'ted',
#        'qvvf1', 'qvvf2', 'qvvf3', 'tvvf1', 'tvvf2', 'tvvf3', 'qsd', 'tsd',
#        'qpc', 'qre', 'qsv', 'pc', 'mc', 'trml', 'trav', 'trve', 'trvp', 'tra',
#        'trv', 'tep', 'tem', 'tvgi', 'tvmd', 'vt', 'class'],
#       dtype='object')
#          count      mean       std  min       25%       50%       75%  max
# iv     56424.0  0.658922  0.269406  0.0  0.495558  0.719145  0.888669  1.0
# im     56424.0  0.625453  0.305747  0.0  0.478643  0.688346  0.896101  1.0
# ium    56424.0  0.566853  0.261266  0.0  0.519263  0.666108  0.707984  1.0
# dp     56424.0  0.089742  0.095794  0.0  0.025597  0.063492  0.124109  1.0
# qc     56424.0  0.000301  0.012626  0.0  0.000000  0.000000  0.000000  1.0
# qa     56424.0  0.000445  0.008873  0.0  0.000000  0.000000  0.000000  1.0
# qf     56424.0  0.000222  0.007651  0.0  0.000000  0.000000  0.000000  1.0
# qt     56424.0  0.000052  0.004680  0.0  0.000000  0.000000  0.000000  1.0
# qb     56424.0  0.004387  0.023099  0.0  0.000000  0.000000  0.000000  1.0
# tb     56424.0  0.004803  0.026804  0.0  0.000000  0.000000  0.000000  1.0
# qmo    56424.0  0.007784  0.039713  0.0  0.000000  0.000000  0.000000  1.0
# tmo    56424.0  0.003729  0.022949  0.0  0.000000  0.000000  0.000000  1.0
# qrf1   56424.0  0.003433  0.023801  0.0  0.000000  0.000000  0.000000  1.0
# qvf1   56424.0  0.000375  0.007147  0.0  0.000000  0.000000  0.000000  1.0
# qvf2   56424.0  0.000284  0.013639  0.0  0.000000  0.000000  0.000000  1.0
# qvf3   56424.0  0.000071  0.007291  0.0  0.000000  0.000000  0.000000  1.0
# tvf1   56424.0  0.000220  0.006599  0.0  0.000000  0.000000  0.000000  1.0
# tvf2   56424.0  0.000081  0.005499  0.0  0.000000  0.000000  0.000000  1.0
# tvf3   56424.0  0.000024  0.004281  0.0  0.000000  0.000000  0.000000  1.0
# ted    56424.0  0.109056  0.108887  0.0  0.041383  0.079709  0.137159  1.0
# qvvf1  56424.0  0.005328  0.034992  0.0  0.000000  0.000000  0.000000  1.0
# qvvf2  56424.0  0.002671  0.021537  0.0  0.000000  0.000000  0.000000  1.0
# qvvf3  56424.0  0.003367  0.030528  0.0  0.000000  0.000000  0.000000  1.0
# tvvf1  56424.0  0.001054  0.013855  0.0  0.000000  0.000000  0.000000  1.0
# tvvf2  56424.0  0.000804  0.012252  0.0  0.000000  0.000000  0.000000  1.0
# tvvf3  56424.0  0.001036  0.014927  0.0  0.000000  0.000000  0.000000  1.0
# qsd    56424.0  0.000284  0.016837  0.0  0.000000  0.000000  0.000000  1.0
# tsd    56424.0  0.000245  0.012006  0.0  0.000000  0.000000  0.000000  1.0
# qpc    56424.0  0.000062  0.006981  0.0  0.000000  0.000000  0.000000  1.0
# qre    56424.0  0.002605  0.024409  0.0  0.000000  0.000000  0.000000  1.0
# qsv    56424.0  0.003191  0.025513  0.0  0.000000  0.000000  0.000000  1.0
# pc     56424.0  0.001012  0.008698  0.0  0.000021  0.000181  0.000582  1.0
# mc     56424.0  0.012796  0.020257  0.0  0.001765  0.007849  0.017446  1.0
# trml   56424.0  0.011615  0.029200  0.0  0.000000  0.002575  0.010942  1.0
# trav   56424.0  0.012762  0.037433  0.0  0.000000  0.000849  0.008068  1.0
# trve   56424.0  0.020007  0.047088  0.0  0.000000  0.003516  0.017929  1.0
# trvp   56424.0  0.054245  0.079550  0.0  0.000000  0.020820  0.081295  1.0
# tra    56424.0  0.019241  0.047553  0.0  0.000000  0.000742  0.016333  1.0
# trv    56424.0  0.002519  0.023524  0.0  0.000000  0.000000  0.000000  1.0
# tep    56424.0  0.082398  0.186120  0.0  0.002033  0.008033  0.027933  1.0
# tem    56424.0  0.110515  0.104978  0.0  0.042322  0.083297  0.144132  1.0
# tvgi   56424.0  0.000503  0.015578  0.0  0.000000  0.000000  0.000000  1.0
# tvmd   56424.0  0.002716  0.027149  0.0  0.000040  0.000040  0.000040  1.0
# vt     56424.0  0.570038  0.122162  0.0  0.600000  0.600000  0.600000  1.0
# class  56424.0  2.511591  1.043533  0.0  3.000000  3.000000  3.000000  3.0

# %% [markdown]
# ## Criando Rede Neural com Pytorch
# * Preparar os dados
# * Definir o modelo
# * Treinar o modelo
# * Avaliar o modelo
# * Predição

# %% [markdown]
# ## Função que utiliza a classe dataset para realizar a preparação de dados
#
# * Classe especializada para controlar acesso aos dados
# * Transformar entrada e saída para modo numérico
# * Configurações no dataset
#     * normalização
#     * codificação
#     *etc
#
# * Normalmente é realizado override das funções:
#     * __len__() retorna tamannho do dataset
#     * __getitem__() obtém uma amostra pelo índice

# %%
class CSVDataset(Dataset):
    def __init__(self, path):
        df = pd.read_csv(path)
        self.X = df.values[:, :-1]
        self.y = df.values[:, -1]
        # ensure input data is floats
        self.X = self.X.astype('float32')
        self.y = LabelEncoder().fit_transform(self.y)
        self.y = self.y.astype('float32')
        self.y = self.y.reshape((len(self.y), 1))
 
    def __len__(self):
        return len(self.X)
 
    def __getitem__(self, idx):
        return [self.X[idx], self.y[idx]]
 
    def get_splits(self, n_test=0.33):
        test_size = round(n_test * len(self.X))
        train_size = len(self.X) - test_size
        return random_split(self, [train_size, test_size])

# %%
dataset = CSVDataset('../dataset/ionosphere.csv')
dataset.__getitem__(10)
dataset.__len__()
# Out:
# 351

# %% [markdown]
# ## Cria estruturas DataLoader para padronizar a leitura de dados

# %%
def prepare_data(path, batch_size):
    dataset = CSVDataset(path)
    train, test = dataset.get_splits()
    train_dl = DataLoader(train, batch_size=batch_size, shuffle=True)
    test_dl = DataLoader(test, batch_size=batch_size, shuffle=False)   
    print('Dataset length (total, train, test):', len(dataset), len(train_dl.dataset), len(test_dl.dataset))
    return train_dl, test_dl

# %%
prepare_data('../dataset/ionosphere.csv', batch_size=32)
# Out:
# Dataset length (total, train, test): 351 235 116
# (<torch.utils.data.dataloader.DataLoader at 0x7f9a2f2a01d0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f99878b0bd0>)

# %% [markdown]
# ## Função para treino do modelo
#
# * Extendendo classe torch.nn.Module
#     * Modelos genéricos de rede Neural
#
# * Contrutor da classe define as camadas do modelo
# * Função forward() é a substituição que define como encaminhar a propagação de entrada pelas camadas definidas do modelo
# * Pode ser definida a camada Linear para camadas totalmente conectadas e Conv2d para camadas convolucionais
# * Funções de ativação também podem ser definidas como camadas, como ReLU, Softmax e Sigmoid

# %%
class MLP(Module):
    def __init__(self, n_inputs):
        super(MLP, self).__init__()
        
        # camada de entrada
        self.hidden1 = Linear(n_inputs, 10)
        # Inicialização da camada de entrada
        kaiming_uniform_(self.hidden1.weight, nonlinearity='relu')
        # Ativação da camada de entrada
        self.act1 = ReLU()
        
        # segunda camada , entrada tem que ser do mesmo tamanho da saida da camada 1
        self.hidden2 = Linear(10, 8)
        kaiming_uniform_(self.hidden2.weight, nonlinearity='relu')
        self.act2 = ReLU()
        
        # camada de saída
        self.hidden3 = Linear(8, 1)
        xavier_uniform_(self.hidden3.weight)
        self.act3 = Sigmoid()
 
    # propagação da entrada pelas camadas
    def forward(self, X):
        # input to first hidden layer
        X = self.hidden1(X)
        X = self.act1(X)
        X = self.hidden2(X)
        X = self.act2(X)
        X = self.hidden3(X)
        X = self.act3(X)
        return X

# %% [markdown]
# ## O processo de treinamento
#
# * Dfinir uma função de perda e um algoritmo de otimização
#
# * Funções comuns de perda:
#     * BCELoss: Perda de entropia cruzada binária para classificação binária
#     * CrossEntropyLoss: perda de entropia cruzada categórica para classificação de várias classes
#     * MSELoss: perda quadrática média para regressão.
#
# * SGD é o algoritmo de otimização padrão

# %% [markdown]
# ## Treinamento do modelo
# * Enumeração do DataLoader para o conjunto de dados de treinamento
#
# * Loop para o número de épocas de treinamento
#     * Loop interno para os mini-lotes para a descida do gradiente estocástico

# %% [markdown]
# ## Cada atualização do modelo envolve o mesmo padrão geral
#
# * Limpando o último gradiente de erro
# * Uma passagem (forward) direta da entrada pelo modelo
# * Calculando a perda para a saída do modelo
# * Retropropagando o erro através do modelo
# * Atualize o modelo em um esforço para reduzir a perda (otimização)

# %%
def train_model(train_dl, model, epochs):
    # define loss
    criterion = BCELoss()
    # define otimizador
    optimizer = SGD(model.parameters(), lr=0.01, momentum=0.9)
    for epoch in range(epochs):
        # Loop em conjunto de mini-batches
        for i, (predictors, y_true) in enumerate(train_dl):
            # zera os gradientes do batches
            optimizer.zero_grad()
            # predição do batch
            y_hat = model(predictors)
            # calcula loss
            loss = criterion(y_hat, y_true)
            # Retroprapagando erros 
            loss.backward()
            # atualiza pesos (otimização)
            optimizer.step()
        if epoch % (epochs/10) == 0: print('Current loss of %.2f after %d epochs' % (loss, epoch+1))

# %% [markdown]
# ## Avaliação do modelo

# %%
def evaluate_model(test_dl, model):
    predictions, actuals = list(), list()
    # percorre lista do dataloader de test
    for i, (predictors, y_true) in enumerate(test_dl):
        # realiza predição
        y_hat = model(predictors)
        # cria numpy array
        y_hat = y_hat.detach().numpy()
        y_true = y_true.numpy()
        y_true = y_true.reshape((len(y_true), 1))
        # round valores da classe
        y_hat = y_hat.round()
        predictions.append(y_hat)
        actuals.append(y_true)        
    predictions, actuals = np.vstack(predictions), np.vstack(actuals)
    # usa sklearn para calcular acurácia
    acc = accuracy_score(actuals, predictions)
    return acc

# %% [markdown]
# ## Recebe uma linha do dataset e calcula a predição

# %%
def predict(predictors, model):
    # convert linha do dataset para tensor
    predictors = Tensor([predictors])
    y_hat = model(predictors)
    y_hat = y_hat.detach().numpy()
    return y_hat

# %% [markdown]
# # Treinando uma rede MLP usando PyTorch

# %%
path = '../dataset/ionosphere.csv'
#path = 'dataset/transport.csv'
inputs = 34 # 34 for ionosphere or 44 for transport
epochs = 100

train_dl, test_dl = prepare_data(path, batch_size=32)

model = MLP(inputs)
train_model(train_dl, model, epochs)
acc = evaluate_model(test_dl, model)
print('Accuracy: %.3f' % acc)

# testa uma predição (por exemplo se o modelo fosse transformado em uma API)
predictors = [1,0,0.99539,-0.05889,0.85243,0.02306,0.83398,-0.37708,1,0.03760,0.85243,-0.17755,0.59755,-0.44945,0.60536,-0.38223,0.84356,-0.38542,0.58212,-0.32192,0.56971,-0.29674,0.36946,-0.47357,0.56811,-0.51171,0.41078,-0.46168,0.21266,-0.34090,0.42267,-0.54487,0.18641,-0.45300]
y_hat = predict(predictors, model)
print('Predicted: %.3f (class=%d)' % (y_hat, y_hat.round()))
# Out:
# Dataset length (total, train, test): 351 235 116
# Current loss of 0.69 after 1 epochs
# Current loss of 0.25 after 11 epochs
# Current loss of 0.19 after 21 epochs
# Current loss of 0.12 after 31 epochs
# Current loss of 0.28 after 41 epochs
# Current loss of 0.04 after 51 epochs
# Current loss of 0.05 after 61 epochs
# Current loss of 0.01 after 71 epochs
# Current loss of 0.01 after 81 epochs
# Current loss of 0.02 after 91 epochs
# Accuracy: 0.931
# Predicted: 0.992 (class=1)

# %% [markdown]
# # Treinando uma rede CNN usando PyTorch

# %% [markdown]
# ## Utiliza função interna do torch para carregar mnist

# %%
# load mnist dataset in pytorch
from torchvision.datasets import MNIST

# define location to save or load the dataset
path = '~/.torch/datasets/mnist'
batch_size = 32

# define the transforms to apply to the data
trans = Compose([ToTensor()])

# download and define the datasets
train = MNIST(path, train=True, download=True, transform=trans)
test = MNIST(path, train=False, download=True, transform=trans)

# define how to enumerate the datasets
train_dl = DataLoader(train, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(test, batch_size=batch_size, shuffle=True)

# get one batch of images
i, (inputs, targets) = next(enumerate(train_dl))
print(i)

# plot some images
fig, axes = pyplot.subplots(figsize=(15,8))
for i in range(25):
    pyplot.subplot(5, 5, i+1)
    pyplot.imshow(inputs[i][0], cmap='gray')
pyplot.show()
# Out:
# 0

# %% [markdown]
# ## Função de preparação de dados para Mnist

# %%
def prepare_MNIST_data(path, trans, batch_size):
    train = MNIST(path, train=True, download=True, transform=trans)
    test = MNIST(path, train=False, download=True, transform=trans)
    train_dl = DataLoader(train, batch_size=batch_size, shuffle=True)
    test_dl = DataLoader(train, batch_size=batch_size, shuffle=False)    
    return train_dl, test_dl

path = '~/.torch/datasets/mnist'
trans = Compose([ToTensor(), Normalize((0.1307,), (0.3081,))])
batch_size = 32
prepare_MNIST_data(path, trans, batch_size)
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7f9959ebef10>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f995a726490>)

# %% [markdown]
# ## Função para carregar dados de arquivos
# * Adicionando collate_fn=utils.collate_fn para montar mini-batches

# %%
trans = Compose([ToTensor()])

train = ImageFolder(root='/home/lazarop/Downloads/dogs-vs-cats/subset/train', transform=trans)
test = ImageFolder(root='/home/lazarop/Downloads/dogs-vs-cats/subset/test', transform=trans)
batch_size = 32

train_dl = DataLoader(train, batch_size=batch_size, shuffle=True, collate_fn=utils.collate_fn)
test_dl = DataLoader(test, batch_size=batch_size, shuffle=True, collate_fn=utils.collate_fn)

# get one batch of images
i, (inputs, targets) = next(enumerate(train_dl))

fig, axes = pyplot.subplots(figsize=(15,8))
for i in range(25):
    pyplot.subplot(5, 5, i+1)
    pyplot.imshow(inputs[i][0], cmap='gray')
pyplot.show()

# %% [markdown]
# ## Função preparada para ler dados de arquivos

# %%
def prepare_data(path, trans, batch_size):
    train = ImageFolder(root=path+'train', transform=trans)
    test = ImageFolder(root=path+'test', transform=trans)
    train_dl = DataLoader(train, batch_size=batch_size, shuffle=True, collate_fn=utils.collate_fn)
    test_dl = DataLoader(train, batch_size=batch_size, shuffle=False, collate_fn=utils.collate_fn)    
    return train_dl, test_dl

path = '/home/lazarop/Downloads/dogs-vs-cats/subset/'
trans = Compose([ToTensor(), Normalize((0.1307,), (0.3081,))])
batch_size = 32
prepare_data(path, trans, batch_size)
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7f995a874690>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f995a874490>)

# %%
class CNN(Module):
    def __init__(self, n_channels):
        super(CNN, self).__init__()
        # input to first hidden layer
        self.hidden1 = Conv2d(n_channels, 32, (3,3))
        kaiming_uniform_(self.hidden1.weight, nonlinearity='relu')
        self.act1 = ReLU()
        self.pool1 = MaxPool2d((2,2), stride=(2,2))
        # second hidden layer
        self.hidden2 = Conv2d(32, 32, (3,3))
        kaiming_uniform_(self.hidden2.weight, nonlinearity='relu')
        self.act2 = ReLU()
        self.pool2 = MaxPool2d((2,2), stride=(2,2))
        # fully connected layer
        self.hidden3 = Linear(5*5*32, 100)
        kaiming_uniform_(self.hidden3.weight, nonlinearity='relu')
        self.act3 = ReLU()
        # output layer
        self.hidden4 = Linear(100, 10)
        xavier_uniform_(self.hidden4.weight)
        self.act4 = Softmax(dim=1)
 
    def forward(self, X):
        X = self.hidden1(X)
        X = self.act1(X)
        X = self.pool1(X)
        X = self.hidden2(X)
        X = self.act2(X)
        X = self.pool2(X)
        # flatten
        X = X.view(-1, 4*4*50)
        X = self.hidden3(X)
        X = self.act3(X)
        X = self.hidden4(X)
        X = self.act4(X)
        return X 

# train the model
def train_model(train_dl, model, epochs):
    criterion = CrossEntropyLoss()
    optimizer = SGD(model.parameters(), lr=0.01, momentum=0.9)
    for epoch in range(epochs):
        for i, (predictors, y_true) in enumerate(train_dl):
            optimizer.zero_grad()
            y_hat = model(predictors)
            loss = criterion(y_hat, y_true)
            loss.backward()
            optimizer.step()
        if epoch % (epochs/10) == 0 or epochs < 20: print('Current loss of %.2f after %d epochs' % (loss, epoch+1))

def evaluate_model(test_dl, model):
    predictions, actuals = list(), list()
    for i, (predictors, y_true) in enumerate(test_dl):
        y_true = y_true.numpy()
        y_true = y_true.reshape((len(y_true), 1))
        y_hat = model(predictors)
        y_hat = y_hat.detach().numpy()
        y_hat = np.argmax(y_hat, axis=1)
        y_hat = y_hat.reshape((len(y_hat), 1))
        y_hat = y_hat.round()
        predictions.append(y_hat)
        actuals.append(y_true)        
    predictions, actuals = np.vstack(predictions), np.vstack(actuals)
    acc = accuracy_score(actuals, predictions)
    return acc

def prepare_MNIST_data(path, trans, batch_size):
    train = MNIST(path, train=True, download=True, transform=trans)
    test = MNIST(path, train=False, download=True, transform=trans)
    train_dl = DataLoader(train, batch_size=batch_size, shuffle=True)
    test_dl = DataLoader(train, batch_size=batch_size, shuffle=False)    
    return train_dl, test_dl


path = '~/.torch/datasets/mnist'
trans = Compose([ToTensor(), Normalize((0.1307,), (0.3081,))])
batch_size = 32
epochs = 5

train_dl, test_dl = prepare_MNIST_data(path, trans, batch_size)

model = CNN(1)
train_model(train_dl, model, epochs)
acc = evaluate_model(test_dl, model)
print('Accuracy: %.3f' % acc)
# Out:
# Current loss of 1.52 after 1 epochs
# Current loss of 1.59 after 2 epochs
# Current loss of 1.64 after 3 epochs
# Current loss of 1.46 after 4 epochs
# Current loss of 1.49 after 5 epochs
# Accuracy: 0.989
