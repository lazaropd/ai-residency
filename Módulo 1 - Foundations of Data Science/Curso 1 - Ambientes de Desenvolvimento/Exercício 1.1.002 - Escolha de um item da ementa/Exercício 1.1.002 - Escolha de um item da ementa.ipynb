# %%
# %%HTML
# <script>
#   function code_toggle() {
#     if(code_shown){$('div.input').hide('500');$('#toggleButton').val('Mostrar códigos');$('#friendlyMsg').show();}
#     else{$('div.input').show('500');$('#toggleButton').val('Esconder códigos');$('#friendlyMsg').hide();}
#     code_shown = !code_shown
#   }
#   $(document).ready(function(){code_shown=false;$('div.input').hide()});
# </script>
# <div id="friendlyMsg">Para melhor visualização, os códigos foram escondidos. Clique no botão para revelar.</div><br>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Mostrar códigos"></form>
# Out:
# <script>
#   function code_toggle() {
#     if(code_shown){$('div.input').hide('500');$('#toggleButton').val('Mostrar códigos');$('#friendlyMsg').show();}
#     else{$('div.input').show('500');$('#toggleButton').val('Esconder códigos');$('#friendlyMsg').hide();}
#     code_shown = !code_shown
#   }
#   $(document).ready(function(){code_shown=false;$('div.input').hide()});
# </script>
# <div id="friendlyMsg">Para melhor visualização, os códigos foram escondidos. Clique no botão para revelar.</div><br>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Mostrar códigos"></form>

# %% [markdown]
# # Matplolib
#
# <br>
#
# It's a Python plotting library, inspired by MATLAB, meaning that the terms used (Axis, Figure, Plots) will be similar to those used in MATLAB.
#
# It can be used both within a Python system (via the object-oriented API) but also in more convenient form in Jupyter and IPython notebooks via the Pyplot interface.

# %% [markdown]
# # Pyplot
#
# <br>
#
# PyPlot is a shell-like interface to Matplotlib, to make it easier to use for people who are used to MATLAB.
#
# Pyplot maintains state across calls.
#
# Useful for use in Jupyter or IPython notebooks.
#
# Your can import it via the matplotlib.pyplot namespace.

# %%
from IPython.display import display, Markdown

import matplotlib.pyplot as plt
import numpy as np

display(Markdown("# Exemplo de uso<br><br>"))

script = """>```
x = np.linspace(0, 10, 30)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x, y1, '.-r')
plt.plot(x, y2, 'x-g')
plt.legend(['sin', 'cos'])
plt.title('Exemplo de aplicação do Pyplot')
plt.show()
```"""
display(Markdown(script))
# Out:
# # Exemplo de uso<br><br>
# >```
# x = np.linspace(0, 10, 30)
# y1 = np.sin(x)
# y2 = np.cos(x)
# plt.plot(x, y1, '.-r')
# plt.plot(x, y2, 'x-g')
# plt.legend(['sin', 'cos'])
# plt.title('Exemplo de aplicação do Pyplot')
# plt.show()
# ```

# %%
from IPython.display import display, Markdown

import matplotlib.pyplot as plt
import numpy as np

display(Markdown("# Resultado<br><br>"))


x = np.linspace(0, 10, 30)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x, y1, '.-r')
plt.plot(x, y2, 'x-g')
plt.legend(['sin', 'cos'])
plt.title("Exemplo de aplicação do Pyplot")
plt.show()
# Out:
# # Resultado<br><br>

# %%
from IPython.display import display, YouTubeVideo

vid_code = "qErBw-R2Ybk"
video = YouTubeVideo(vid_code, width=640, height=480)

display(video)
